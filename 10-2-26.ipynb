# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmujeeb-design/2025-2026-4089-Mujeeb-AI-B-DS/blob/main/10-2-26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas and create simple data
#selection particular column and rows
import pandas as pd
data={
    'id':[101,102,103,104,105],
    'name':['a','b','c','d','e'],
    'age':[20,21,19,17,18],
    'marks':[85,78,92,88,98]
}
df=pd.dataframe(data)
print(df)
print(df.loc[1:3],)
