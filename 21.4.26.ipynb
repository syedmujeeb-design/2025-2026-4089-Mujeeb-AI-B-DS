# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmujeeb-design/2025-2026-4089-Mujeeb-AI-B-DS/blob/main/21.4.26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score,recall_score,f1_score,roc_curve,auc
import matplotlib.pyplot as plt
y_true=[0,0,1,0,1,0,1,0]
y_pred=[1,0,0,0,1,0,1,1]
cm=confusion_matrix(y_true,y_pred)
print("confusion_matrix",cm)
print("precision:",precision_score(y_true,y_pred))
print("recall:",recall_score(y_true,y_pred))
print("F1score:",f1_score(y_true,y_pred))
y_score=[0.9,0.6,0.8,0.3,0.4,0.2,0.05,0.1]
fpr,tpr,_=roc_curve(y_true,y_pred)
roc_auc=auc(fpr,tpr)
print("AUC:",roc_auc)
plt.plot(fpr,tpr)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("RDC CURVE")
plt.show()
# Out:
# confusion_matrix [[3 2]
#  [1 2]]
# precision: 0.5
# recall: 0.6666666666666666
# F1score: 0.5714285714285714
# AUC: 0.6333333333333333

# %%
from sklearn import svm
x=[[2,2],[4,4],[2,0],[0,2]]
y=[1,1,-1,-1]
model=svm.SVC(kernel="linear")
model.fit(x,y)
print(model.predict([[0,0]]))
# Out:
# [-1]

# %%
from sklearn.tree import DecisionTreeClassifier
x=[[1,1],[1,0],[0,1],[0,0]]
y=[0,1,1,0]
model=DecisionTreeClassifier()
model.fit(x,y)
print(model.predict([[1,0]]))
# Out:
# [1]
